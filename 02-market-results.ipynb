# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Example DataFrame
data = {
    "mechanism": [
        "AVG",
        "Mcafee",
        "TR",
        "VCG",
        "AVG",
        "Mcafee",
        "TR",
        "VCG",
        "AVG",
        "Mcafee",
        "TR",
        "VCG",
        "AVG",
        "Mcafee",
        "TR",
        "VCG",
    ],
    "count": [
        7805,
        7652,
        2774,
        7689,
        6908,
        6962,
        1092,
        10958,
        25,
        0,
        20214,
        5681,
        6102,
        6312,
        6256,
        7250,
    ],
    "goal": [
        "traded_unit_p2p_vs_infra",
        "traded_unit_p2p_vs_infra",
        "traded_unit_p2p_vs_infra",
        "traded_unit_p2p_vs_infra",
        "profit_p2p_vs_infra",
        "profit_p2p_vs_infra",
        "profit_p2p_vs_infra",
        "profit_p2p_vs_infra",
        "profit_auctioneer",
        "profit_auctioneer",
        "profit_auctioneer",
        "profit_auctioneer",
        "total_profit_players",
        "total_profit_players",
        "total_profit_players",
        "total_profit_players",
    ],
}

df = pd.DataFrame(data)

# Create the catplot
# sns.set_style("whitegrid")
# plt.figure(figsize=(10, 8))
# plt.suptitle('Overall view of buyers and sellers units over 3 years', fontsize=18)

sns.catplot(
    data=df,
    x="mechanism",
    y="count",
    col="goal",
    kind="bar",
    height=4,
    aspect=0.6,
)
plt.savefig('goal_counts.pdf', dpi=2000)

# %%
import pandas as pd
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

y=pd.read_csv('labels.csv')
y=y.drop(columns='Unnamed: 0')

c=Counter(y['0'])
#avg, mcafee, tr, vcg
d={'AVG': 21.52,
 'McAfee':  21.17,
 'TR':  15.60,
 'VCG':  41.7}
df = pd.DataFrame(list(d.items()), columns=['Mechanism', 'Percentage'])
# plt.figure(figsize=(10, 6))
sns.barplot(y='Percentage', x='Mechanism', data=df, palette='viridis')
for i, v in enumerate(df['Percentage']):
    plt.text(i, v, "{:.2f}%".format(v), ha='center', fontsize=14)
# plt.title('Percentage of label counts over 25870 rounds', fontsize=16)
plt.ylabel('Percentage (%)', fontsize=14)
plt.xlabel('Mechanism', fontsize=14)
plt.savefig('labels_count.pdf', dpi=2000)
# Out:
# /tmp/ipykernel_344827/1031525712.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='Percentage', x='Mechanism', data=df, palette='viridis')
